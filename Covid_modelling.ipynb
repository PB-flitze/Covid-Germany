# %%
import pandas as pd 
coronaData = pd.read_csv("corona.csv",sep=(';'),decimal=(','))

# %%
coronaData
# Out:
#      dateRep,year_week,cases_weekly,deaths_weekly,countriesAndTerritories,geoId,countryterritoryCode,popData2019,continentExp,notification_rate_per_100000_population_14-days
# 0     14/12/2020,2020-50,1757,71,Afghanistan,AF,AFG,...
# 1     07/12/2020,2020-49,1672,137,Afghanistan,AF,AFG...
# 2     30/11/2020,2020-48,1073,68,Afghanistan,AF,AFG,...
# 3     23/11/2020,2020-47,1368,69,Afghanistan,AF,AFG,...
# 4     16/11/2020,2020-46,1164,61,Afghanistan,AF,AFG,...
# ...                                                 ...
# 8910  20/04/2020,2020-16,11,0,Zimbabwe,ZW,ZWE,146454...
# 8911  13/04/2020,2020-15,5,2,Zimbabwe,ZW,ZWE,1464547...
# 8912  06/04/2020,2020-14,2,0,Zimbabwe,ZW,ZWE,1464547...
# 8913  30/03/2020,2020-13,5,1,Zimbabwe,ZW,ZWE,1464547...
# 8914  23/03/2020,2020-12,2,0,Zimbabwe,ZW,ZWE,1464547...
#
# [8915 rows x 1 columns]

# %% [markdown]
# ## show all headlines

# %%
coronaData.columns
#coronaData.skiprows([1,3151])
# Out:
# Index(['dateRep,year_week,cases_weekly,deaths_weekly,countriesAndTerritories,geoId,countryterritoryCode,popData2019,continentExp,notification_rate_per_100000_population_14-days'], dtype='object')

# %% [markdown]
# ## show only Data from germany

# %% [markdown]
# ### Problem: die eingelesene .csv Datei hat Amerikanische Kommaseparierung daher erkennt es die Spalten noch nicht.

# %%
coronaData.iloc[3151:3201]
# Out:
#      dateRep,year_week,cases_weekly,deaths_weekly,countriesAndTerritories,geoId,countryterritoryCode,popData2019,continentExp,notification_rate_per_100000_population_14-days
# 3151  14/12/2020,2020-50,153424,3056,Germany,DE,DEU,...
# 3152  07/12/2020,2020-49,129785,2671,Germany,DE,DEU,...
# 3153  30/11/2020,2020-48,124736,2136,Germany,DE,DEU,...
# 3154  23/11/2020,2020-47,127806,1565,Germany,DE,DEU,...
# 3155  16/11/2020,2020-46,129459,1195,Germany,DE,DEU,...
# 3156  09/11/2020,2020-45,126841,822,Germany,DE,DEU,8...
# 3157  02/11/2020,2020-44,107161,474,Germany,DE,DEU,8...
# 3158  26/10/2020,2020-43,71567,267,Germany,DE,DEU,83...
# 3159  19/10/2020,2020-42,40968,168,Germany,DE,DEU,83...
# 3160  12/10/2020,2020-41,24712,87,Germany,DE,DEU,830...
# 3161  05/10/2020,2020-40,15287,74,Germany,DE,DEU,830...
# 3162  28/09/2020,2020-39,12995,74,Germany,DE,DEU,830...
# 3163  21/09/2020,2020-38,11982,36,Germany,DE,DEU,830...
# 3164  14/09/2020,2020-37,9556,25,Germany,DE,DEU,8301...
# ...

# %%
for index, row in coronaData.iterrows():
    coronaData.skiprows
    print(index,row)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-743c6189c204> in <module>
# ----> 1 for index, row in coronaData.iloc[3151:3201]:
#       2     print(index,row)
#
# ValueError: too many values to unpack (expected 2)
